# %%
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
df = pd.read_csv('../Data/donors.csv')
# Out:
# C:\Users\josem\.conda\envs\python-standard\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (9,412) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
df
# Out:
#        Unnamed: 0     ODATEDW OSOURCE  TCODE STATE    ZIP MAILCODE PVASTATE  \
# 0               0  2009-01-01     GRI      0    IL  61081
# 1               1  2014-01-01     BOA      1    CA  91326
# 2               2  2010-01-01     AMH      1    NC  27017
# 3               3  2007-01-01     BRY      0    CA  95953
# 4               4  2006-01-01              0    FL  33176
# ...           ...         ...     ...    ...   ...    ...      ...      ...
# 95407       95407  2016-01-01     ASE      1    AK  99504
# 95408       95408  2016-01-01     DCD      1    TX  77379
# 95409       95409  2015-01-01     MBC      1    MI  48910
# 95410       95410  2006-01-01     PRV      0    CA  91320
# 95411       95411  2008-01-01     MCC      2    NC  28409
#
#               DOB NOEXCH  ...    AVGGIFT CONTROLN HPHONE_D RFA_2R RFA_2F  \
# 0      1957-12-01      0  ...   7.741935    95515        0      L      4
# 1      1972-02-01      0  ...  15.666667   148535        0      L      2
# ...

# %%
interests = [
'COLLECT1',
'VETERANS',
'BIBLE',
'CATLG',
'HOMEE',
'PETS',
'CDPLAY',
'STEREO',
'PCOWNERS',
'PHOTO',
'CRAFTS',
'FISHER',
'GARDENIN',
'BOATS',
'WALKER',
'KIDSTUFF',
'CARDS',
'PLATES',
'LIFESRC'
]

mags = [
'MBCRAFT',
'MBGARDEN',
'MBBOOKS',
'MBCOLECT',
'MAGFAML',
'MAGFEM',
'MAGMALE',
'PUBGARDN',
'PUBCULIN',
'PUBHLTH',
'PUBDOITY',
'PUBNEWFN',
'PUBPHOTO',
'PUBOPP'
]

contributions = [
'HIT',
'RFA_2R',
'RFA_2F',
'RFA_2A',
'MDMAUD_R',
'MDMAUD_F',
'MDMAUD_A'
]

demographic = ['DOB', 
               'MDMAUD',
               'DOMAIN', 
               'NUMCHLD', 
               'INCOME', 
               'GENDER', 
               'WEALTH1', 
               'HIT', 
               'MAJOR']

# %%
working_df = df[contributions]
working_df
# Out:
#        HIT RFA_2R  RFA_2F RFA_2A MDMAUD_R MDMAUD_F MDMAUD_A
# 0        0      L       4      E        X        X        X
# 1       16      L       2      G        X        X        X
# 2        2      L       4      E        X        X        X
# 3        2      L       4      E        X        X        X
# 4       60      L       2      F        X        X        X
# ...    ...    ...     ...    ...      ...      ...      ...
# 95407    0      L       1      G        X        X        X
# 95408    1      L       1      F        X        X        X
# 95409    0      L       3      E        X        X        X
# 95410    0      L       4      F        X        X        X
# 95411    3      L       1      G        C        1        C
#
# [95412 rows x 7 columns]

# %%
for x in df[demographic].columns: 
    print(df[x].unique())
# Out:
# ['1957-12-01' '1972-02-01' nan '1948-01-01' '1940-01-01' '1980-01-01'
#  '1952-11-01' '1943-01-01' '1946-03-01' '1947-09-01' '1974-01-01'
#  '1972-01-01' '1956-01-01' '1936-01-01' '1943-11-01' '1963-07-01'
#  '1976-01-01' '1934-01-01' '1968-09-01' '1946-01-01' '1949-04-01'
#  '1949-01-01' '1930-02-01' '1933-11-01' '1988-01-01' '1973-10-01'
#  '1966-11-01' '1951-10-01' '2010-08-01' '1957-06-01' '1950-01-01'
#  '1934-11-01' '1972-10-01' '1957-03-01' '1978-01-01' '1970-01-01'
#  '1984-01-01' '1938-01-01' '1982-01-01' '1968-01-01' '1977-01-01'
#  '1938-05-01' '1946-08-01' '1964-03-01' '1945-12-01' '1948-07-01'
#  '1956-05-01' '1971-01-01' '1964-01-01' '1952-01-01' '1985-01-01'
#  '1955-01-01' '1954-01-01' '1958-12-01' '1941-01-01' '1944-10-01'
#  '1931-01-01' '1967-07-01' '2000-09-01' '1934-08-01' '1949-09-01'
#  '1959-01-01' '1940-06-01' '1932-06-01' '1966-01-01' '1966-12-01'
#  '1957-01-01' '1941-08-01' '1992-01-01' '1954-06-01' '1942-01-01'
# ...
